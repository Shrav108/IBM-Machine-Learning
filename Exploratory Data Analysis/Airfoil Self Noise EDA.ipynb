# %% [markdown]
# ### Import Libraries

# %%
import matplotlib.pyplot as plt  # Plotting Library
import numpy as np               # Numpy Library
import pandas as pd              # Dataframe Library
from scipy.stats.mstats import normaltest # Import normaltest
import seaborn as sns # Seaborn

# %% [markdown]
# ### Data

# %%
df = pd.read_csv('AirfoilSelfNoise.csv') # Read CSV
df.head() # Peek
# Out:
#       f  alpha       c  U_infinity     delta     SSPL
# 0   800    0.0  0.3048        71.3  0.002663  126.201
# 1  1000    0.0  0.3048        71.3  0.002663  125.201
# 2  1250    0.0  0.3048        71.3  0.002663  125.951
# 3  1600    0.0  0.3048        71.3  0.002663  127.591
# 4  2000    0.0  0.3048        71.3  0.002663  127.461

# %% [markdown]
# ### Describe Data

# %%
df.describe() # Describe Data
# Out:
#                   f        alpha            c   U_infinity        delta  \
# count   1503.000000  1503.000000  1503.000000  1503.000000  1503.000000
# mean    2886.380572     6.782302     0.136548    50.860745     0.011140
# std     3152.573137     5.918128     0.093541    15.572784     0.013150
# min      200.000000     0.000000     0.025400    31.700000     0.000401
# 25%      800.000000     2.000000     0.050800    39.600000     0.002535
# 50%     1600.000000     5.400000     0.101600    39.600000     0.004957
# 75%     4000.000000     9.900000     0.228600    71.300000     0.015576
# max    20000.000000    22.200000     0.304800    71.300000     0.058411
#
#               SSPL
# count  1503.000000
# mean    124.835943
# std       6.898657
# min     103.380000
# 25%     120.191000
# 50%     125.721000
# 75%     129.995500
# max     140.987000

# %% [markdown]
# ### Correlation

# %%
corr = df.corr() # Correlation
plt.figure(figsize=(8,8)) # Figure
sns.heatmap(corr, cmap="Blues", annot=True) # Heatmap
plt.title('Correlation Matrix', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.show() # Show

# %% [markdown]
# ### Box Plot

# %%
fig_box = plt.figure(figsize =(8, 6))  # Figure size.
ax = fig_box.add_subplot(111)          # Subplot is used because to give colors to the plot as it can be iterable.
fig_box = ax.boxplot(df['f'], patch_artist=True, vert=1) # Plot the box chart.
plt.title('Box Plot of Frequency Feature', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('Frequency', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
plt.grid(True)
for whisker in fig_box['whiskers']:                                # Add color to whisker.
    whisker.set(color ='blue',linewidth = 1.5)
for cap in fig_box['caps']:                                        # Add color to cap.
    cap.set(color ='blue', linewidth = 6) 
for median in fig_box['medians']:                                  # Add color to median.
    median.set(color ='white',linewidth = 3) 
for patch in fig_box['boxes']:                                     # Add color to patch.
    patch.set_facecolor(color='red') 
plt.show()                                                         # Display plot.

# %%
fig_box = plt.figure(figsize =(8, 6))  # Figure size.
ax = fig_box.add_subplot(111)          # Subplot is used because to give colors to the plot as it can be iterable.
fig_box = ax.boxplot(df['alpha'], patch_artist=True, vert=1) # Plot the box chart.
plt.title('Box Plot of Angle of Attack', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('Angle of Attack', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
plt.grid(True)
for whisker in fig_box['whiskers']:                                # Add color to whisker.
    whisker.set(color ='blue',linewidth = 1.5)
for cap in fig_box['caps']:                                        # Add color to cap.
    cap.set(color ='blue', linewidth = 6) 
for median in fig_box['medians']:                                  # Add color to median.
    median.set(color ='white',linewidth = 3) 
for patch in fig_box['boxes']:                                     # Add color to patch.
    patch.set_facecolor(color='green') 
plt.show()

# %%
fig_box = plt.figure(figsize =(8, 6))  # Figure size.
ax = fig_box.add_subplot(111)          # Subplot is used because to give colors to the plot as it can be iterable.
fig_box = ax.boxplot(df['c'], patch_artist=True, vert=1) # Plot the box chart.
plt.grid(True) # Grid
plt.title('Box Plot of Chord Length', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('Chord Length', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
for whisker in fig_box['whiskers']:                                # Add color to whisker.
    whisker.set(color ='blue',linewidth = 1.5)
for cap in fig_box['caps']:                                        # Add color to cap.
    cap.set(color ='blue', linewidth = 6) 
for median in fig_box['medians']:                                  # Add color to median.
    median.set(color ='white',linewidth = 3) 
for patch in fig_box['boxes']:                                     # Add color to patch.
    patch.set_facecolor(color='magenta') 
plt.show()

# %%
fig_box = plt.figure(figsize =(8, 6))  # Figure size.
ax = fig_box.add_subplot(111)          # Subplot is used because to give colors to the plot as it can be iterable.
fig_box = ax.boxplot(df['U_infinity'], patch_artist=True, vert=1) # Plot the box chart.
plt.grid(True) # Grid
plt.title('Box Plot of Free Stream Velocity', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('Free Stream Velocity', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
for whisker in fig_box['whiskers']:                                # Add color to whisker.
    whisker.set(color ='blue',linewidth = 1.5)
for cap in fig_box['caps']:                                        # Add color to cap.
    cap.set(color ='blue', linewidth = 6) 
for median in fig_box['medians']:                                  # Add color to median.
    median.set(color ='white',linewidth = 3) 
for patch in fig_box['boxes']:                                     # Add color to patch.
    patch.set_facecolor(color='yellow') 
plt.show()

# %%
fig_box = plt.figure(figsize =(8, 6))  # Figure size.
ax = fig_box.add_subplot(111)          # Subplot is used because to give colors to the plot as it can be iterable.
fig_box = ax.boxplot(df['delta'], patch_artist=True, vert=1) # Plot the box chart.
plt.grid(True) # Grid
plt.title('Box Plot of Suction side displacement thickness', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('Suction side displacement thickness', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
for whisker in fig_box['whiskers']:                                # Add color to whisker.
    whisker.set(color ='blue',linewidth = 1.5)
for cap in fig_box['caps']:                                        # Add color to cap.
    cap.set(color ='blue', linewidth = 6) 
for median in fig_box['medians']:                                  # Add color to median.
    median.set(color ='white',linewidth = 3) 
for patch in fig_box['boxes']:                                     # Add color to patch.
    patch.set_facecolor(color='brown') 
plt.show()

# %%
fig_box = plt.figure(figsize =(8, 6))  # Figure size.
ax = fig_box.add_subplot(111)          # Subplot is used because to give colors to the plot as it can be iterable.
fig_box = ax.boxplot(df['SSPL'], patch_artist=True, vert=1) # Plot the box chart.
plt.grid(True) # Grid
plt.title('Box Plot of Noise', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('Noise', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
for whisker in fig_box['whiskers']:                                # Add color to whisker.
    whisker.set(color ='blue',linewidth = 1.5)
for cap in fig_box['caps']:                                        # Add color to cap.
    cap.set(color ='blue', linewidth = 6) 
for median in fig_box['medians']:                                  # Add color to median.
    median.set(color ='white',linewidth = 3) 
for patch in fig_box['boxes']:                                     # Add color to patch.
    patch.set_facecolor(color='orange') 
plt.show()

# %% [markdown]
# ### Histograms

# %%
plt.figure(figsize=(7,5)) # Figure
plt.hist(df['f'], bins = 50)  # Histogram
plt.grid(True) # Grid
plt.title('Histogram of Frequency Feature', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('Frequency', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
plt.show() # Show

# %%
plt.figure(figsize=(7,5)) # Figure
plt.hist(df['alpha'], bins = 50)  # Histogram
plt.grid(True) # Grid
plt.title('Histogram of Angle of Attack', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('Angle of Attack', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
plt.show() # Show

# %%
plt.figure(figsize=(7,5)) # Figure
plt.hist(df['c'], bins = 50)  # Histogram
plt.grid(True) # Grid
plt.title('Histogram of Chord Length', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('Chord Length', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
plt.show() # Show

# %%
plt.figure(figsize=(7,5)) # Figure
plt.hist(df['U_infinity'], bins = 50)  # Histogram
plt.grid(True) # Grid
plt.title('Histogram of Free Stream Velocity', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('Free Stream Velocity', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
plt.show() # Show

# %%
plt.figure(figsize=(7,5)) # Figure
plt.hist(df['delta'], bins = 50)  # Histogram
plt.grid(True) # Grid
plt.title('Histogram of Suction side displacement thickness', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('Suction side displacement thickness', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
plt.show() # Show

# %% [markdown]
# #### Data Description

# %% [markdown]
#     Input features:
#
#         f: Frequency in Hertzs [Hz].
#         alpha: Angle of attack (AoA, α), in degrees [°].
#         c: Chord length, in meters [m].
#         U_infinity: Free-stream velocity, in meters per second [m/s].
#         delta: Suction side displacement thickness (𝛿), in meters [m].
#
#     Output:
#
#         SSPL: Scaled sound pressure level, in decibels [dB]

# %% [markdown]
# ### Data Exploration

# %% [markdown]
#     Determine Normality
#
#     1. If the target variable is Normally distributed, it obtains better results.
#
#     2. If our target is not normally distributed, we can apply a transformation to it and then fit
#        our regression to predict the transformed values.
#
#     3. To see if target values are normally distributed, check:
#         a. Visualy
#         b. Statistically

# %% [markdown]
# #### Hypothesis
#
#     Null Hypothesis: The target values are normally distributed.
#     Alternate Hypothesis: The target values are not normally distributed.

# %% [markdown]
# #### Visual Test: Plot Histogram of target

# %%
plt.figure(figsize=(7,5)) # Figure
plt.hist(df['SSPL'], bins = 50)  # Histogram
plt.grid(True) # Grid
plt.title('Histogram of SSPL Distribution', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('SSPL', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
plt.show() # Show

# %% [markdown]
# ##### The histogram is not normally distributed. We have to transform it.

# %% [markdown]
# #### Statistic Test: Check with p-value

# %%
normaltest(df['SSPL']) # Normal Test
# Out:
# NormaltestResult(statistic=49.45069509012877, pvalue=1.8277550732540224e-11)

# %% [markdown]
#     Note: Statisticians say if p > 0.05, then the dataset is normally distributed. Here, since p-value
#       is less than 0.05, it is not normally distributed, so we reject the Null Hypothesis.

# %% [markdown]
# #### Transformation
#
#     1. Linear Regression assumes a normal distributed residuals. So, we have to transform the target
#        variables.
#     2. Some transformation which can make a non-normally distributed to a normally distributed are:
#        a. Log Transformation
#        b. Square Root Transformation
#        c. Box-Cox Transformation
#        d. Inverse Transformation
#        e. Yeo-Johnson Transformation

# %% [markdown]
# #### Transformation

# %%
log_y = np.log10(df['SSPL']) # Log Transformation
sqrt_y = np.sqrt(df['SSPL'])  # Square Root Transformation
box_y = boxcox(df['SSPL']) # Box Cox Transformation
inv_y = np.array(1/df['SSPL']) # Inverse Transformation

# %%
print('Log Transformation p-value:', normaltest(log_y))
print('*******************************************************')
print('SquareRoot Transformation p-val:', normaltest(sqrt_y))
print('*******************************************************')
print('Box Cox Transformation p-value:', normaltest(box_y[0]))
print('*******************************************************')
print('Inverse Transformation p-value:', normaltest(inv_y))
# Out:
# Log Transformation p-value: NormaltestResult(statistic=67.99079399949862, pvalue=1.721815737185587e-15)
# *******************************************************
# SquareRoot Transformation p-val: NormaltestResult(statistic=57.35720201056755, pvalue=3.5078566279140157e-13)
# *******************************************************
# Box Cox Transformation p-value: NormaltestResult(statistic=35.67116789274296, pvalue=1.7951647448346226e-08)
# *******************************************************
# Inverse Transformation p-value: NormaltestResult(statistic=97.97788318234974, pvalue=5.301185393463406e-22)

# %%
plt.figure(figsize=(7,5)) # Figure
plt.hist(log_y, bins = 50, color='blue')  # Histogram
plt.grid(True) # Grid
plt.title('Histogram of SSPL Distribution-Log Transformation', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('LOG SSPL', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
plt.show() # Show

# %%
plt.figure(figsize=(7,5)) # Figure
plt.hist(sqrt_y, bins = 50, color='green')  # Histogram
plt.grid(True) # Grid
plt.title('Histogram of SSPL Distribution-Square Root Transformation', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('SQRT SSPL', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
plt.show() # Show

# %%
plt.figure(figsize=(7,5)) # Figure
plt.hist(box_y[0], bins = 50, color='red')  # Histogram
plt.grid(True) # Grid
plt.title('Histogram of SSPL Distribution-Box Cox Transformation', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('Box Cox SSPL', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
plt.show() # Show

# %%
plt.figure(figsize=(7,5)) # Figure
plt.hist(inv_y, bins = 50, color='brown')  # Histogram
plt.grid(True) # Grid
plt.title('Histogram of SSPL Distribution-Inverse Transformation', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('Inverse SSPL', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
plt.show() # Show

# %% [markdown]
# #### Let us try Yeo-Johnson Transformation

# %%
scaler = StandardScaler() # Normalizer
yj_y = scaler.fit_transform(df[['SSPL']]) # Normalize

# %%
pt = PowerTransformer(method='yeo-johnson') # Yeo-Johnson Transfromation
yj_y = pt.fit_transform(yj_y) # Transform

# %%
normaltest(yj_y) # Chek P-vlaue
# Out:
# NormaltestResult(statistic=masked_array(data=[31.256482077076225],
#              mask=[False],
#        fill_value=1e+20), pvalue=array([1.63207892e-07]))

# %%
plt.figure(figsize=(7,5)) # Figure
plt.hist(yj_y, bins = 50, color='orange')  # Histogram
plt.grid(True) # Grid
plt.title('Histogram of SSPL Distribution-Yeo-Johnson Transformation', fontdict={'fontsize':18, 'fontweight':'semibold'}) # Title
plt.xlabel('SQRT SSPL', fontdict={'fontsize':14, 'fontweight':'semibold'}) # X-Label
plt.ylabel('Density', fontdict={'fontsize':14, 'fontweight':'semibold'}) # Y-Label
plt.show() # Show

# %% [markdown]
# ### Note:
#     1. With the implementation all the transformation, the p-value is not increasing above 0.05.
#        The best transformation is the Yeo-Johnson Transformation with the least p-value.
#
#     2. Since we did not get a p-value above 0.05, we do not transform the data.
